# %% [markdown]
# # COVID-19 Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
try:
    path = 'C:\\Users\\shyam\\AppData\\Local\\Programs\\Python\\Python37-32\\'
    global_filename = 'COVID-19_Global_Data.csv'
    india_filename = 'COVID-19_India_Data.csv'
    df = pd.read_csv(path + global_filename, encoding="ISO-8859-1")
    df2 = pd.read_csv(path + india_filename, encoding="ISO-8859-1")
    technology = os.path.basename(path).split('_')[0]
except Exception as e:
    print(f'EXCEPTION: {e}')

# %%
df.head()
# Out:
#         DATE  TOTAL_CASES  DEATHS
# 0  19-Mar-20       236877    9828
# 1  20-Mar-20       255901   10495

# %%
df2.head()
# Out:
#              DATE  TOTAL_CASES  DEATHS
# 0  March 19, 2020          173       4
# 1       20-Mar-20          223       4

# %% [markdown]
# ## Data Across World

# %%
plt.plot(df['DATE'], df['DEATHS'], color='green')
plt.title('No. of Deaths - Across World\n', fontsize= 20)
plt.xlabel('Dates')
plt.ylabel('No. of Deaths')
plt.show()

# %%
plt.plot(df['DATE'], df['TOTAL_CASES'], color="green")
plt.title('No. of Cases - Across World\n', fontsize= 20)
plt.xlabel('Dates')
plt.ylabel('No. of Cases')
plt.show()

# %% [markdown]
# ## Data Across India

# %%
plt.plot(df2['DATE'], df2['DEATHS'], color="coral")
plt.title('No. of Deaths - Across India\n', fontsize= 20)
plt.xlabel('Dates')
plt.ylabel('No. of Deaths')
plt.show()

# %%
plt.plot(df2['DATE'], df2['TOTAL_CASES'], color="coral")
plt.title('No. of Cases - Across India\n', fontsize= 20)
plt.xlabel('Dates')
plt.ylabel('No. of Cases')
plt.show()
